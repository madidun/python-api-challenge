# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
geoapify_key = "6be0c4e7c4ee4b5ebf0332246d4ce298"

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        thompson  55.7435  -97.8558     12.09        43          75
# 1        1  ribeira grande  38.5167  -28.7000     21.22        88          20
# 2        2          fuyang  32.9000  115.8167     25.86        44           0
# 3        3      vikasnagar  30.4683   77.7750     29.96        44          83
# 4        4          bethel  41.3712  -73.4140     25.86        63          20
#
#    Wind Speed Country        Date
# 0        3.60      CA  1686764699
# 1        7.60      PT  1686764614
# 2        3.29      CN  1686765080
# 3        1.94      IN  1686765081
# 4        5.14      US  1686764479

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
base_url = "https://api.geoapify.com/v1/geocode/search?text=38%20Upper%20Montagu%20Street%2C%20Westminster%20W1H%201LJ%2C%20United%20Kingdom&apiKey=6be0c4e7c4ee4b5ebf0332246d4ce298"

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humiidity",
    scale = 2,
    color = "City",
)

# Display the map
map_plot
# Out:
# WARNING:param.GeoPointPlot01832: Specified size dim transform (np.sqrt(dim('Humiidity'))*2) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_df = city_data_df.loc[(city_data_df["Cloudiness"] == 0) & (city_data_df["Humidity"] < 60)]
# Drop any rows with null values
filtered_df = filtered_df.dropna()

# Display sample data
filtered_df
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 2          2                fuyang  32.9000  115.8167     25.86        44
# 8          8                 vadso  70.0744   29.7487     14.49        54
# 18        18                  arar  30.9753   41.0381     35.01        12
# 82        82               awjilah  29.1081   21.2869     32.82        24
# 83        83                 smara  26.7384  -11.6719     29.62        31
# 95        95              notodden  59.5594    9.2585     27.92        26
# 102      102               estevan  49.1334 -102.9842     27.19        57
# 137      137               stanley  54.8680   -1.6985     19.77        47
# 144      144               tir pul  34.5943   61.2690     30.79        13
# 176      176               karbala  32.6160   44.0249     35.16        19
# 192      192               alamosa  37.4695 -105.8700     17.99        34
# 197      197                ixtapa  20.7000 -105.2000     30.57        58
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_df.loc[:,["City","Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 2                  fuyang      CN  32.9000  115.8167        44
# 8                   vadso      NO  70.0744   29.7487        54
# 18                   arar      SA  30.9753   41.0381        12
# 82                awjilah      LY  29.1081   21.2869        24
# 83                  smara      EH  26.7384  -11.6719        31
# 95               notodden      NO  59.5594    9.2585        26
# 102               estevan      CA  49.1334 -102.9842        57
# 137               stanley      GB  54.8680   -1.6985        47
# 144               tir pul      AF  34.5943   61.2690        13
# 176               karbala      IQ  32.6160   44.0249        19
# 192               alamosa      US  37.4695 -105.8700        34
# 197                ixtapa      MX  20.7000 -105.2000        58
# 199             yaroslavl      RU  57.6299   39.8737        55
# 202                 chios      GR  38.3678   26.1358        57
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 8000
params = {
    "categories": "hotel options",
    "apikey": geoapify_key,
    "radius" : radius
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params) 
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# fuyang - nearest hotel: No hotel found
# vadso - nearest hotel: No hotel found
# arar - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# smara - nearest hotel: No hotel found
# notodden - nearest hotel: No hotel found
# estevan - nearest hotel: No hotel found
# stanley - nearest hotel: No hotel found
# tir pul - nearest hotel: No hotel found
# karbala - nearest hotel: No hotel found
# alamosa - nearest hotel: No hotel found
# ixtapa - nearest hotel: No hotel found
# yaroslavl - nearest hotel: No hotel found
# chios - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: No hotel found
# kuusamo - nearest hotel: No hotel found
# chui - nearest hotel: No hotel found
# muynoq - nearest hotel: No hotel found
# san jose del cabo - nearest hotel: No hotel found
# saint joseph - nearest hotel: No hotel found
# chiredzi - nearest hotel: No hotel found
# al burayqah - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humiidity",
    scale = 2,
    color = "City",
    hover_cols = ["City","Humidity","Hotel Name"],

)

# Display the map
map_plot
# Out:
# WARNING:param.GeoPointPlot01965: Specified size dim transform (np.sqrt(dim('Humiidity'))*2) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
